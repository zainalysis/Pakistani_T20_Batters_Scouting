# %%
from google.colab import drive

# Mount Google Drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-1-0908f5a56395> in <cell line: 4>()
#       2
#       3 # Mount Google Drive
# ----> 4 drive.mount('/content/drive')
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      98 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      99   """Mount your Google Drive at the specified mountpoint path."""
# --> 100   return _mount(
#     101       mountpoint,
#     102       force_remount=force_remount,
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     275             'https://research.google.com/colaboratory/faq.html#drive-timeout'
#     276         )
# --> 277       raise ValueError('mount failed' + extra_reason)
#     278     elif case == 4:
#     279       # Terminate the DriveFS binary before killing bash.
#
# ValueError: mount failed

# %%
import pandas as pd

file_path = '/content/drive/My Drive/t20_bbb.csv'
df = pd.read_csv(file_path)

df.head()
# Out:
# <ipython-input-2-3b93432e2326>:4: DtypeWarning: Columns (51,52,53) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
#    p_match  inns          bat  p_bat   team_bat            bowl  p_bowl  \
# 0  1001349     1  Aaron Finch   5334  Australia  Lasith Malinga   49758
# 1  1001349     1  Aaron Finch   5334  Australia  Lasith Malinga   49758
# 2  1001349     1  Aaron Finch   5334  Australia  Lasith Malinga   49758
# 3  1001351     1  Aaron Finch   5334  Australia  Lasith Malinga   49758
# 4  1001351     1  Aaron Finch   5334  Australia  Lasith Malinga   49758
#
#    team_bowl  ball  ball_id  ... bat_out  wagonX  wagonY wagonZone  \
# 0  Sri Lanka     1     0.01  ...    True   208.0   178.0       3.0
# 1  Sri Lanka     2     0.02  ...    True   243.0   175.0       3.0
# 2  Sri Lanka     3     0.03  ...    True   189.0   242.0       4.0
# 3  Sri Lanka     3     0.03  ...    True   166.0   194.0       5.0
# 4  Sri Lanka     4     0.04  ...    True    15.0   222.0       6.0
#
#                line                  length      shot  control  predscore  \
# 0     ON_THE_STUMPS  SHORT_OF_A_GOOD_LENGTH  DEFENDED      0.0       -1.0
# 1     ON_THE_STUMPS             GOOD_LENGTH  DEFENDED      1.0       -1.0
# 2     ON_THE_STUMPS  SHORT_OF_A_GOOD_LENGTH  DEFENDED      0.0       -1.0
# 3  OUTSIDE_OFFSTUMP  SHORT_OF_A_GOOD_LENGTH  DEFENDED      1.0       -1.0
# 4  OUTSIDE_OFFSTUMP             GOOD_LENGTH  CUT_SHOT      1.0       -1.0
#
#    wprob
# 0   -1.0
# 1   -1.0
# 2   -1.0
# 3   -1.0
# 4   -1.0
#
# [5 rows x 57 columns]

# %%
import pandas as pd

# Filter rows where the country is Pakistan
pakistan_df = df[df['country'] == 'Pakistan']

# Function to calculate average length of consecutive 0 or 1 patterns
def calculate_average_pattern_length(batruns):
    lengths = []  # List to store lengths of consecutive patterns
    current_pattern = []  # Track the current pattern of 0s or 1s

    for value in batruns:
        if value in [0, 1]:  # Continue the pattern
            current_pattern.append(value)
        else:  # Pattern breaks
            if current_pattern:  # Only process if there's a valid pattern
                lengths.append(len(current_pattern))
            current_pattern = []  # Reset the pattern

    if current_pattern:  # Handle remaining pattern at the end
        lengths.append(len(current_pattern))

    return sum(lengths) / len(lengths) if lengths else 0

# Group by 'bat' and calculate the average pattern length for each batter
results = {}
for bat, group in pakistan_df.groupby('bat'):
    average_length = calculate_average_pattern_length(group['batruns'].tolist())
    results[bat] = average_length

# Convert results to a DataFrame for better readability
results_df = pd.DataFrame(list(results.items()), columns=['Batter', 'Average_Consecutive_Pattern_Length'])

# Display the results
print(results_df)

# Optionally save to a CSV file
results_df.to_csv('/content/average_pattern_lengths_pakistan.csv', index=False)
# Out:
#              Batter  Average_Consecutive_Pattern_Length
# 0       Aamer Azmat                            4.133333
# 1        Aamer Ijaz                            5.833333
# 2       Aamer Jamal                            3.870968
# 3       Aamer Yamin                            3.714286
# 4     Aaqib Liaquat                            4.333333
# ..              ...                                 ...
# 535    Zohaib Ahmed                            7.000000
# 536     Zohaib Khan                            5.277778
# 537    Zohaib Shera                            2.000000
# 538     Zubair Khan                            7.500000
# 539  Zulfiqar Babar                            5.250000
#
# [540 rows x 2 columns]

# %%
# Set pandas display options to show maximum rows and columns
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# Convert results to a DataFrame for better readability
results_df = pd.DataFrame(list(results.items()), columns=['Batter', 'Average_Consecutive_Pattern_Length'])

# Display the results
print(results_df)
# Out:
#                          Batter  Average_Consecutive_Pattern_Length
# 0                   Aamer Azmat                            4.133333
# 1                    Aamer Ijaz                            5.833333
# 2                   Aamer Jamal                            3.870968
# 3                   Aamer Yamin                            3.714286
# 4                 Aaqib Liaquat                            4.333333
# 5                   Aaron Finch                            3.666667
# 6                  Abbas Afridi                            3.500000
# 7                   Abdul Ameer                            5.000000
# 8               Abdul Bangalzai                            5.234043
# 9             Abdullah Shafique                            4.209040
# 10                 Abdur Rehman                            7.000000
# 11                     Abid Ali                            5.533333
# 12                  Abrar Ahmed                            4.500000
# 13                    Adam Lyth                            2.777778
# 14                   Adam Milne                            2.000000
# 15              Adam Rossington                            3.692308
# 16                  Adeel Malik                            4.307692
# 17                    Adil Amin                            5.433333
# 18                     Adil Naz                            1.000000
# 19                  Adil Rashid                            1.000000
# 20                  Adnan Akmal                            4.000000
# 21                  Adnan Raees                            4.571429
# 22                   Afaq Ahmed                            2.500000
# 23                  Afaq Raheem                            4.302326
# 24                 Afif Hossain                            9.666667
# 25                Aftab Ibrahim                            2.000000
# 26                  Aftab Niazi                            5.400000
# 27                  Agha Salman                            4.244681
# 28                 Ahmed Bashir                            7.000000
# 29                   Ahmed Butt                            2.333333
# 30                  Ahmed Jamal                            2.000000
# 31                   Ahmed Khan                            4.666667
# 32                Ahmed Rasheed                            3.000000
# 33          Ahmed Safi Abdullah                            6.666667
# 34                Ahmed Shehzad                            4.385000
# 35                    Ahsan Ali                            4.687500
# 36                 Ahsan Hafeez                            3.000000
# 37                   Aimal Khan                            2.000000
# 38                 Aizaz Cheema                            9.000000
# 39              Akbar-ur-Rehman                            4.333333
# 40                 Akeal Hosein                            5.428571
# 41                   Akif Javed                            5.500000
# 42                   Alex Hales                            4.251613
# 43                    Ali Imran                            3.733333
# 44                     Ali Khan                            4.705882
# 45                    Ali Majid                            5.000000
# 46                  Ali Sarfraz                            4.722222
# 47                   Ali Shafiq                           12.000000
# 48                     Ali Shan                            8.000000
# 49                    Ali Waqas                            7.000000
# 50                    Amad Butt                            3.617021
# 51                 Aminul Islam                            2.000000
# 52                   Ammad Alam                            3.500000
# 519                 Younis Khan                            3.818182
# 520                Yousuf Babar                            1.500000
# 521                 Zafar Gohar                            4.333333
# 522               Zahid Mahmood                            6.625000
# 523               Zahid Mansoor                            4.935484
# 524                  Zahir Khan                            1.000000
# 525               Zahir Siddiqi                            4.000000
# 526                  Zain Abbas                            4.552632
# 527              Zakary Foulkes                            1.000000
# 528                  Zaman Khan                           10.000000
# 529              Zeeshan Ashraf                            4.051282
# 530                 Zeeshan Gul                            1.000000
# 531               Zeeshan Malik                            4.129032
# 532             Zeeshan Mushtaq                            2.000000
# 533              Zeeshan Zameer                            1.000000
# 534                  Zia-ul-Haq                            3.800000
# 535                Zohaib Ahmed                            7.000000
# 536                 Zohaib Khan                            5.277778
# 537                Zohaib Shera                            2.000000
# 538                 Zubair Khan                            7.500000
# 539              Zulfiqar Babar                            5.250000

# %%
import pandas as pd



# Filter rows where the country is Pakistan
pakistan_df = df[df['country'] == 'Pakistan']

# Filter batters with at least 50 unique p_match entries
batters_with_50_matches = (
    pakistan_df.groupby('bat')['p_match']
    .nunique()
    .reset_index()
    .rename(columns={'p_match': 'unique_matches'})
)
batters_with_50_matches = batters_with_50_matches[batters_with_50_matches['unique_matches'] >= 20]
qualified_batters = batters_with_50_matches['bat'].tolist()

# Function to calculate average length of consecutive 0 or 1 patterns
def calculate_average_pattern_length(batruns):
    lengths = []  # List to store lengths of consecutive patterns
    current_pattern = []  # Track the current pattern of 0s or 1s

    for value in batruns:
        if value in [0, 1]:  # Continue the pattern
            current_pattern.append(value)
        else:  # Pattern breaks
            if current_pattern:  # Only process if there's a valid pattern
                lengths.append(len(current_pattern))
            current_pattern = []  # Reset the pattern

    if current_pattern:  # Handle remaining pattern at the end
        lengths.append(len(current_pattern))

    return sum(lengths) / len(lengths) if lengths else 0

# Group by 'bat' and calculate the average pattern length for qualified batters
results = {}
for bat, group in pakistan_df.groupby('bat'):
    if bat in qualified_batters:  # Consider only qualified batters
        average_length = calculate_average_pattern_length(group['batruns'].tolist())
        results[bat] = average_length

# Convert results to a DataFrame for better readability
results_df = pd.DataFrame(list(results.items()), columns=['Batter', 'Average_Consecutive_Pattern_Length'])

# Set pandas display options to show maximum rows and columns
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
# Display the results
print(results_df)

# Optionally save to a CSV file
results_df.to_csv('/content/average_pattern_lengths_pakistan_qualified.csv', index=False)
# Out:
#                  Batter  Average_Consecutive_Pattern_Length
# 0           Aamer Yamin                            3.714286
# 1     Abdullah Shafique                            4.209040
# 2             Adil Amin                            5.433333
# 3           Agha Salman                            4.244681
# 4         Ahmed Shehzad                            4.385000
# 5             Ahsan Ali                            4.687500
# 6       Akbar-ur-Rehman                            4.333333
# 7            Alex Hales                            4.251613
# 8             Amad Butt                            3.617021
# 9             Anwar Ali                            4.454545
# 10          Asad Shafiq                            4.352381
# 11             Asif Ali                            4.308511
# 12            Awais Zia                            4.569767
# 13            Azam Khan                            4.133333
# 14           Babar Azam                            4.033546
# 15          Ben Cutting                            3.822581
# 16           Bilal Asif                            4.695652
# 17       Bismillah Khan                            4.156863
# 18          Colin Munro                            4.021739
# 19          Danish Aziz                            5.187500
# 20          David Wiese                            3.530303
# 21        Faheem Ashraf                            4.304348
# 22         Fakhar Zaman                            4.560976
# 23           Haider Ali                            4.174603
# 24          Hammad Azam                            5.172414
# 25         Haris Sohail                            5.223404
# 26            Hasan Ali                            3.944444
# 27        Hussain Talat                            4.604651
# 28       Iftikhar Ahmed                            4.761905
# 29           Imad Wasim                            3.798883
# 30          Imam-ul-Haq                            4.875706
# 31           Irfan Khan                            4.543478
# 32           Israrullah                            4.063830
# 33          James Vince                            4.026786
# 34            Jason Roy                            4.069231
# 35         Kamran Akmal                            3.667797
# 36        Kamran Ghulam                            4.790476
# 37      Khurram Manzoor                            4.222826
# 38        Khushdil Shah                            4.571429
# 39       Kieron Pollard                            3.786667
# 40        Mohammad Amir                            4.058824
# 41      Mohammad Hafeez                            4.366812
# 42       Mohammad Haris                            3.453704
# 43       Mohammad Nawaz                            5.062937
# 44      Mohammad Rizwan                            4.161491
# 45       Mohammad Wasim                            4.615385
# 46      Muhammad Akhlaq                            5.142857
# 47        Mukhtar Ahmed                            3.462963
# 48        Musadiq Ahmed                            4.771429
# 49          Naseem Shah                            3.875000
# 50         Nauman Anwar                            3.890411
# 51            Phil Salt                            3.767442
# 52          Qasim Akram                            3.441860
# 53   Rafatullah Mohmand                            3.609524
# 54        Rilee Rossouw                            4.071895
# 55         Rohail Nazir                            4.339623
# 56        Rovman Powell                            3.677966
# 57         Rumman Raees                            4.266667
# 58           Saad Nasim                            6.608696
# 59     Sahibzada Farhan                            4.473054
# 60            Saim Ayub                            3.728682
# 61       Sarfaraz Ahmed                            4.761421
# 62         Saud Shakeel                            4.464286
# 63          Shadab Khan                            3.708920
# 64  Shaheen Shah Afridi                            4.731707
# 65          Shan Masood                            4.395189
# 66        Sharjeel Khan                            4.210811
# 67  Sherfane Rutherford                            4.175439
# 68         Shoaib Malik                            4.412371
# 69        Sikandar Raza                            4.098039
# 70       Sohaib Maqsood                            4.369565
# 71        Sohail Akhtar                            4.944444
# 72          Sohail Khan                            5.828571
# 73        Sohail Tanvir                            5.065217
# 74   Tom Kohler-Cadmore                            4.397436
# 75           Umaid Asif                            3.363636
# 76           Umar Akmal                            4.352941
# 77            Umar Amin                            5.162338
# 78           Wahab Riaz                            5.184211
# 79           Zain Abbas                            4.552632
# 80       Zeeshan Ashraf                            4.051282

# %%
import pandas as pd


# Filter rows where the country is Pakistan
pakistan_df = df[df['country'] == 'Pakistan']

# Qualified batters from the previous step
qualified_batters = [
    "Aamer Yamin", "Abdullah Shafique", "Adil Amin", "Agha Salman",
    "Ahmed Shehzad", "Ahsan Ali", "Akbar-ur-Rehman", "Alex Hales",
    "Amad Butt", "Anwar Ali", "Asad Shafiq", "Asif Ali", "Awais Zia",
    "Azam Khan", "Babar Azam", "Ben Cutting", "Bilal Asif", "Bismillah Khan",
    "Colin Munro", "Danish Aziz", "David Wiese", "Faheem Ashraf",
    "Fakhar Zaman", "Haider Ali", "Hammad Azam", "Haris Sohail",
    "Hasan Ali", "Hussain Talat", "Iftikhar Ahmed", "Imad Wasim",
    "Imam-ul-Haq", "Irfan Khan", "Israrullah", "James Vince", "Jason Roy",
    "Kamran Akmal", "Kamran Ghulam", "Khurram Manzoor", "Khushdil Shah",
    "Kieron Pollard", "Mohammad Amir", "Mohammad Hafeez", "Mohammad Haris",
    "Mohammad Nawaz", "Mohammad Rizwan", "Mohammad Wasim", "Muhammad Akhlaq",
    "Mukhtar Ahmed", "Musadiq Ahmed", "Naseem Shah", "Nauman Anwar",
    "Phil Salt", "Qasim Akram", "Rafatullah Mohmand", "Rilee Rossouw",
    "Rohail Nazir", "Rovman Powell", "Rumman Raees", "Saad Nasim",
    "Sahibzada Farhan", "Saim Ayub", "Sarfaraz Ahmed", "Saud Shakeel",
    "Shadab Khan", "Shaheen Shah Afridi", "Shan Masood", "Sharjeel Khan",
    "Sherfane Rutherford", "Shoaib Malik", "Sikandar Raza", "Sohaib Maqsood",
    "Sohail Akhtar", "Sohail Khan", "Sohail Tanvir", "Tom Kohler-Cadmore",
    "Umaid Asif", "Umar Akmal", "Umar Amin", "Wahab Riaz", "Zain Abbas",
    "Zeeshan Ashraf"
]

# Function to calculate the average balls between boundaries (4 or 6)
def calculate_avg_balls_between_boundaries(batruns):
    boundary_indices = [i for i, value in enumerate(batruns) if value in [4, 6]]
    intervals = [boundary_indices[i] - boundary_indices[i - 1] for i in range(1, len(boundary_indices))]
    return sum(intervals) / len(intervals) if intervals else 0

# Group by 'bat' and calculate the average balls between boundaries for qualified batters
results = {}
for bat, group in pakistan_df.groupby('bat'):
    if bat in qualified_batters:  # Consider only qualified batters
        average_balls = calculate_avg_balls_between_boundaries(group['batruns'].tolist())
        results[bat] = average_balls

# Convert results to a DataFrame for better readability
results_df = pd.DataFrame(list(results.items()), columns=['Batter', 'Average_Balls_Between_Boundaries'])

# Sort by average balls in ascending order
results_df = results_df.sort_values(by='Average_Balls_Between_Boundaries')

# Display the results
print(results_df)

# Optionally save to a CSV file
results_df.to_csv('/content/average_balls_between_boundaries_pakistan.csv', index=False)
# Out:
#                  Batter  Average_Balls_Between_Boundaries
# 47        Mukhtar Ahmed                          4.139535
# 53   Rafatullah Mohmand                          4.239669
# 48        Musadiq Ahmed                          4.244898
# 35         Kamran Akmal                          4.309249
# 50         Nauman Anwar                          4.395349
# 33          James Vince                          4.492537
# 60            Saim Ayub                          4.535211
# 42       Mohammad Haris                          4.552632
# 66        Sharjeel Khan                          4.555556
# 34            Jason Roy                          4.598726
# 80       Zeeshan Ashraf                          4.627907
# 49          Naseem Shah                          4.714286
# 13            Azam Khan                          4.739130
# 7            Alex Hales                          4.807692
# 39       Kieron Pollard                          4.810127
# 20          David Wiese                          4.811594
# 15          Ben Cutting                          4.818182
# 76           Umar Akmal                          4.853147
# 54        Rilee Rossouw                          4.892857
# 56        Rovman Powell                          4.948276
# 32           Israrullah                          4.980198
# 18          Colin Munro                          5.000000
# 21        Faheem Ashraf                          5.038168
# 70       Sohaib Maqsood                          5.038278
# 0           Aamer Yamin                          5.076923
# 12            Awais Zia                          5.080808
# 51            Phil Salt                          5.097561
# 29           Imad Wasim                          5.127778
# 52          Qasim Akram                          5.142857
# 46      Muhammad Akhlaq                          5.183333
# 69        Sikandar Raza                          5.192308
# 8             Amad Butt                          5.227273
# 37      Khurram Manzoor                          5.230769
# 40        Mohammad Amir                          5.230769
# 64  Shaheen Shah Afridi                          5.319149
# 23           Haider Ali                          5.326425
# 75           Umaid Asif                          5.357143
# 22         Fakhar Zaman                          5.386308
# 74   Tom Kohler-Cadmore                          5.474359
# 11             Asif Ali                          5.500000
# 4         Ahmed Shehzad                          5.507317
# 55         Rohail Nazir                          5.528302
# 41      Mohammad Hafeez                          5.532189
# 63          Shadab Khan                          5.534031
# 67  Sherfane Rutherford                          5.535714
# 5             Ahsan Ali                          5.553398
# 16           Bilal Asif                          5.652174
# 38        Khushdil Shah                          5.714286
# 6       Akbar-ur-Rehman                          5.776119
# 14           Babar Azam                          5.788562
# 10          Asad Shafiq                          5.803922
# 17       Bismillah Khan                          5.847826
# 57         Rumman Raees                          5.909091
# 28       Iftikhar Ahmed                          5.953488
# 71        Sohail Akhtar                          5.963964
# 9             Anwar Ali                          6.035294
# 65          Shan Masood                          6.055762
# 31           Irfan Khan                          6.068182
# 62         Saud Shakeel                          6.151899
# 3           Agha Salman                          6.164706
# 77            Umar Amin                          6.208861
# 1     Abdullah Shafique                          6.328947
# 59     Sahibzada Farhan                          6.386667
# 72          Sohail Khan                          6.394737
# 78           Wahab Riaz                          6.410256
# 27        Hussain Talat                          6.459596
# 68         Shoaib Malik                          6.527344
# 44      Mohammad Rizwan                          6.531017
# 45       Mohammad Wasim                          6.590909
# 36        Kamran Ghulam                          6.593750
# 79           Zain Abbas                          6.609375
# 73        Sohail Tanvir                          6.650000
# 19          Danish Aziz                          6.672131
# 24          Hammad Azam                          6.692308
# 30          Imam-ul-Haq                          6.798742
# 61       Sarfaraz Ahmed                          6.856322
# 43       Mohammad Nawaz                          6.930233
# 26            Hasan Ali                          6.961538
# 25         Haris Sohail                          7.292683
# 2             Adil Amin                          8.711111
# 58           Saad Nasim                          9.351351

# %%
import pandas as pd
import plotly.express as px

# Load the datasets
# Average pattern lengths
pattern_lengths_file = '/content/average_pattern_lengths_pakistan_qualified.csv'
pattern_lengths_df = pd.read_csv(pattern_lengths_file)

# Average balls between boundaries
boundaries_file = '/content/average_balls_between_boundaries_pakistan.csv'
boundaries_df = pd.read_csv(boundaries_file)

# Merge the two datasets on 'Batter'
merged_df = pd.merge(
    pattern_lengths_df,
    boundaries_df,
    on='Batter',
    how='inner'
)

# Create a scatter plot
fig = px.scatter(
    merged_df,
    x='Average_Consecutive_Pattern_Length',
    y='Average_Balls_Between_Boundaries',
    text='Batter',
    title='Scatter Plot: Batting Patterns vs Balls Between Boundaries',
    labels={
        'Average_Consecutive_Pattern_Length': 'Average Consecutive 0 or 1 Pattern Length',
        'Average_Balls_Between_Boundaries': 'Average Balls Between Boundaries'
    },
    hover_name='Batter',
)

# Add batter names as text on the scatter plot
fig.update_traces(textposition='top center')

# Customize layout for better visuals
fig.update_layout(
    xaxis_title='Average Consecutive 0 or 1 Pattern Length',
    yaxis_title='Average Balls Between Boundaries',
    title_font_size=20,
    title_x=0.5,  # Center the title
    template='plotly'  # Use a dark theme for better contrast
)

# Show the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="ba8b0bff-e0ac-47f2-b400-6019926d9028" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ba8b0bff-e0ac-47f2-b400-6019926d9028")) {                    Plotly.newPlot(                        "ba8b0bff-e0ac-47f2-b400-6019926d9028",                        [{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eAverage Consecutive 0 or 1 Pattern Length=%{x}\u003cbr\u003eAverage Balls Between Boundaries=%{y}\u003cbr\u003eBatter=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Aamer Yamin","Abdullah Shafique","Adil Amin","Agha Salman","Ahmed Shehzad","Ahsan Ali","Akbar-ur-Rehman","Alex Hales","Amad Butt","Anwar Ali","Asad Shafiq","Asif Ali","Awais Zia","Azam Khan","Babar Azam","Ben Cutting","Bilal Asif","Bismillah Khan","Colin Munro","Danish Aziz","David Wiese","Faheem Ashraf","Fakhar Zaman","Haider Ali","Hammad Azam","Haris Sohail","Hasan Ali","Hussain Talat","Iftikhar Ahmed","Imad Wasim","Imam-ul-Haq","Irfan Khan","Israrullah","James Vince","Jason Roy","Kamran Akmal","Kamran Ghulam","Khurram Manzoor","Khushdil Shah","Kieron Pollard","Mohammad Amir","Mohammad Hafeez","Mohammad Haris","Mohammad Nawaz","Mohammad Rizwan","Mohammad Wasim","Muhammad Akhlaq","Mukhtar Ahmed","Musadiq Ahmed","Naseem Shah","Nauman Anwar","Phil Salt","Qasim Akram","Rafatullah Mohmand","Rilee Rossouw","Rohail Nazir","Rovman Powell","Rumman Raees","Saad Nasim","Sahibzada Farhan","Saim Ayub","Sarfaraz Ahmed","Saud Shakeel","Shadab Khan","Shaheen Shah Afridi","Shan Masood","Sharjeel Khan","Sherfane Rutherford","Shoaib Malik","Sikandar Raza","Sohaib Maqsood","Sohail Akhtar","Sohail Khan","Sohail Tanvir","Tom Kohler-Cadmore","Umaid Asif","Umar Akmal","Umar Amin","Wahab Riaz","Zain Abbas","Zeeshan Ashraf"],"legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers+text","name":"","orientation":"v","showlegend":false,"text":["Aamer Yamin","Abdullah Shafique","Adil Amin","Agha Salman","Ahmed Shehzad","Ahsan Ali","Akbar-ur-Rehman","Alex Hales","Amad Butt","Anwar Ali","Asad Shafiq","Asif Ali","Awais Zia","Azam Khan","Babar Azam","Ben Cutting","Bilal Asif","Bismillah Khan","Colin Munro","Danish Aziz","David Wiese","Faheem Ashraf","Fakhar Zaman","Haider Ali","Hammad Azam","Haris Sohail","Hasan Ali","Hussain Talat","Iftikhar Ahmed","Imad Wasim","Imam-ul-Haq","Irfan Khan","Israrullah","James Vince","Jason Roy","Kamran Akmal","Kamran Ghulam","Khurram Manzoor","Khushdil Shah","Kieron Pollard","Mohammad Amir","Mohammad Hafeez","Mohammad Haris","Mohammad Nawaz","Mohammad Rizwan","Mohammad Wasim","Muhammad Akhlaq","Mukhtar Ahmed","Musadiq Ahmed","Naseem Shah","Nauman Anwar","Phil Salt","Qasim Akram","Rafatullah Mohmand","Rilee Rossouw","Rohail Nazir","Rovman Powell","Rumman Raees","Saad Nasim","Sahibzada Farhan","Saim Ayub","Sarfaraz Ahmed","Saud Shakeel","Shadab Khan","Shaheen Shah Afridi","Shan Masood","Sharjeel Khan","Sherfane Rutherford","Shoaib Malik","Sikandar Raza","Sohaib Maqsood","Sohail Akhtar","Sohail Khan","Sohail Tanvir","Tom Kohler-Cadmore","Umaid Asif","Umar Akmal","Umar Amin","Wahab Riaz","Zain Abbas","Zeeshan Ashraf"],"x":[3.7142857142857135,4.209039548022599,5.433333333333334,4.24468085106383,4.385,4.6875,4.333333333333333,4.251612903225807,3.617021276595745,4.454545454545454,4.352380952380952,4.308510638297872,4.569767441860465,4.133333333333334,4.033546325878595,3.8225806451612905,4.695652173913044,4.15686274509804,4.021739130434782,5.1875,3.5303030303030303,4.304347826086956,4.560975609756097,4.174603174603175,5.172413793103448,5.223404255319149,3.9444444444444446,4.604651162790698,4.761904761904762,3.798882681564246,4.875706214689266,4.543478260869565,4.0638297872340425,4.02678571428 ...

# %%
import pandas as pd
import plotly.express as px

# Load the datasets
pattern_lengths_file = '/content/average_pattern_lengths_pakistan_qualified.csv'
pattern_lengths_df = pd.read_csv(pattern_lengths_file)

boundaries_file = '/content/average_balls_between_boundaries_pakistan.csv'
boundaries_df = pd.read_csv(boundaries_file)

# Merge the datasets
merged_df = pd.merge(
    pattern_lengths_df,
    boundaries_df,
    on='Batter',
    how='inner'
)

# Define color categories based on conditions
def categorize_color(row):
    if row['Average_Consecutive_Pattern_Length'] < 4.6 and row['Average_Balls_Between_Boundaries'] < 5.51:
        return 'blue'
    elif row['Average_Consecutive_Pattern_Length'] < 5 and row['Average_Balls_Between_Boundaries'] < 6:
        return 'green'
    else:
        return 'red'

# Apply the categorization
merged_df['Color'] = merged_df.apply(categorize_color, axis=1)

# Plot the scatter plot
fig = px.scatter(
    merged_df,
    x='Average_Consecutive_Pattern_Length',
    y='Average_Balls_Between_Boundaries',
    color='Color',
    hover_data=['Batter'],
    title='Scatter Plot of Batting Patterns and Boundary Intervals',
    labels={
        'Average_Consecutive_Pattern_Length': 'Avg. Consecutive 0 or 1 Pattern Length',
        'Average_Balls_Between_Boundaries': 'Avg. Balls Between Boundaries'
    },
)

# Update layout for better appearance
fig.update_layout(
    template='plotly_white',
    legend_title_text='Color Category'
)

# Show the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="a52ec6b7-ba01-40a7-8a69-fba50937173a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("
marker":{"color":"#EF553B","symbol":"circle"},"mode":"markers","name":"red","orientation":"v","showlegend":true,"x":[4.209039548022599,5.433333333333334,4.24468085106383,4.454545454545454,5.1875,5.172413793103448,5.223404255319149,3.9444444444444446,4.604651162790698,4.875706214689266,4.543478260869565,4.79047619047619,5.062937062937063,4.1614906832298 ...

# %%
import pandas as pd


# Filter rows where the country is Pakistan
pakistan_df = df[df['country'] == 'Pakistan']

# Qualified batters from the previous step
qualified_batters = [
    "Aamer Yamin", "Abdullah Shafique", "Adil Amin", "Agha Salman",
    "Ahmed Shehzad", "Ahsan Ali", "Akbar-ur-Rehman", "Alex Hales",
    "Amad Butt", "Anwar Ali", "Asad Shafiq", "Asif Ali", "Awais Zia",
    "Azam Khan", "Babar Azam", "Ben Cutting", "Bilal Asif", "Bismillah Khan",
    "Colin Munro", "Danish Aziz", "David Wiese", "Faheem Ashraf",
    "Fakhar Zaman", "Haider Ali", "Hammad Azam", "Haris Sohail",
    "Hasan Ali", "Hussain Talat", "Iftikhar Ahmed", "Imad Wasim",
    "Imam-ul-Haq", "Irfan Khan", "Israrullah", "James Vince", "Jason Roy",
    "Kamran Akmal", "Kamran Ghulam", "Khurram Manzoor", "Khushdil Shah",
    "Kieron Pollard", "Mohammad Amir", "Mohammad Hafeez", "Mohammad Haris",
    "Mohammad Nawaz", "Mohammad Rizwan", "Mohammad Wasim", "Muhammad Akhlaq",
    "Mukhtar Ahmed", "Musadiq Ahmed", "Naseem Shah", "Nauman Anwar",
    "Phil Salt", "Qasim Akram", "Rafatullah Mohmand", "Rilee Rossouw",
    "Rohail Nazir", "Rovman Powell", "Rumman Raees", "Saad Nasim",
    "Sahibzada Farhan", "Saim Ayub", "Sarfaraz Ahmed", "Saud Shakeel",
    "Shadab Khan", "Shaheen Shah Afridi", "Shan Masood", "Sharjeel Khan",
    "Sherfane Rutherford", "Shoaib Malik", "Sikandar Raza", "Sohaib Maqsood",
    "Sohail Akhtar", "Sohail Khan", "Sohail Tanvir", "Tom Kohler-Cadmore",
    "Umaid Asif", "Umar Akmal", "Umar Amin", "Wahab Riaz", "Zain Abbas",
    "Zeeshan Ashraf"
]

# Function to calculate the average balls between boundaries (4 or 6)
def calculate_avg_balls_between_boundaries(batruns):
    boundary_indices = [i for i, value in enumerate(batruns) if value in [4, 6]]
    intervals = [boundary_indices[i] - boundary_indices[i - 1] for i in range(1, len(boundary_indices))]
    return sum(intervals) / len(intervals) if intervals else 0

# Group by 'bat' and calculate the average balls between boundaries for qualified batters
results = {}
for bat, group in pakistan_df.groupby('bat'):
    if bat in qualified_batters:  # Consider only qualified batters
        average_balls = calculate_avg_balls_between_boundaries(group['batruns'].tolist())
        results[bat] = average_balls

# Convert results to a DataFrame for better readability
results_df = pd.DataFrame(list(results.items()), columns=['Batter', 'Average_Balls_Between_Boundaries'])

# Sort by average balls in ascending order
results_df = results_df.sort_values(by='Average_Balls_Between_Boundaries')

# Display the results
print(results_df)

# Optionally save to a CSV file
results_df.to_csv('/content/average_balls_between_boundaries_pakistan.csv', index=False)
